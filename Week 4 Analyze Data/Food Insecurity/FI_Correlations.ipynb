# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from numpy import nan

# %%
matrix2009 = pd.read_excel("2009_MatrixA.xlsx")

# %%
matrix2009
# Out:
#    State  Food Insecurity   Child Food Insecurity  Unemployment Rate  \
# 0     AK             0.135                  0.212           0.083833
# 1     AL             0.178                  0.266           0.098167
# 2     AR             0.178                  0.286           0.070417
# 3     AZ             0.174                  0.288           0.084583
# 4     CA             0.167                  0.273           0.116167
# 5     CO             0.143                  0.227           0.072750
# 6     CT             0.123                  0.189           0.080250
# 7     DC             0.158                  0.323           0.107833
# 8     DE             0.122                  0.197           0.080500
# 9     FL             0.171                  0.275           0.104167
# 10    GA             0.178                  0.279           0.097917
# 11    HI             0.127                  0.208           0.069917
# 12    IA             0.128                  0.206           0.060000
# ...

# %%
matrix2009.dtypes
# Out:
# State                         object
# Food Insecurity              float64
# Child Food Insecurity        float64
# Unemployment Rate            float64
# 0.5 Income-Poverty Ratio     float64
# 0.75 Income-Poverty Ratio    float64
# 1.0 Income-Poverty Ratio     float64
# 1.25 Income-Poverty Ratio    float64
# 1.5 Income-Poverty Ratio     float64
# 1.75 Income-Poverty Ratio    float64
# 2.0 Income-Poverty Ratio     float64
# Inflation                    float64
# dtype: object

# %%
matrix2009.corr()
# Out:
#                            Food Insecurity   Child Food Insecurity  \
# Food Insecurity                    1.000000               0.911901
# Child Food Insecurity              0.911901               1.000000
# Unemployment Rate                  0.632815               0.608743
# 0.5 Income-Poverty Ratio                NaN                    NaN
# 0.75 Income-Poverty Ratio               NaN                    NaN
# 1.0 Income-Poverty Ratio                NaN                    NaN
# 1.25 Income-Poverty Ratio               NaN                    NaN
# 1.5 Income-Poverty Ratio                NaN                    NaN
# 1.75 Income-Poverty Ratio               NaN                    NaN
# 2.0 Income-Poverty Ratio                NaN                    NaN
# Inflation                               NaN                    NaN
#
#                            Unemployment Rate  0.5 Income-Poverty Ratio  \
# Food Insecurity                     0.632815                       NaN
# ...

# %%
matrix2010 = pd.read_excel("2010 Correlation Matrix .xlsx")

# %%
matrix2010
# Out:
#    State  2010 Food Insecurity Rate  2010 Child Food Insecurity Rate  \
# 0     AK                      0.146                            0.199
# 1     AL                      0.192                            0.267
# 2     AR                      0.192                            0.278
# 3     AZ                      0.190                            0.290
# 4     CA                      0.171                            0.268
# 5     CO                      0.155                            0.221
# 6     CT                      0.138                            0.188
# 7     DC                      0.165                            0.307
# 8     DE                      0.128                            0.184
# 9     FL                      0.192                            0.284
# 10    GA                      0.199                            0.283
# 11    HI                      0.140                            0.217
# 12    IA                      0.134                            0.195
# ...

# %%
matrix2010.dtypes
# Out:
# State                               object
# 2010 Food Insecurity Rate          float64
# 2010 Child Food Insecurity Rate    float64
# Unemployment Rate                  float64
# 0.5 Income-Poverty Ratio           float64
# 0.75 Income-Poverty Ratio          float64
# 1.0 Income-Poverty Ratio           float64
# 1.25 Income-Poverty Ratio          float64
# 1.5 Income-Poverty Ratio           float64
# 1.75 Income-Poverty Ratio          float64
# 2.0 Income-Poverty Ratio           float64
# Inflation                          float64
# 2010 Cost Per Meal                 float64
# dtype: object

# %%
matrix2010.corr()
# Out:
#                                  2010 Food Insecurity Rate  \
# 2010 Food Insecurity Rate                         1.000000
# 2010 Child Food Insecurity Rate                   0.917513
# Unemployment Rate                                 0.646878
# 0.5 Income-Poverty Ratio                               NaN
# 0.75 Income-Poverty Ratio                              NaN
# 1.0 Income-Poverty Ratio                               NaN
# 1.25 Income-Poverty Ratio                              NaN
# 1.5 Income-Poverty Ratio                               NaN
# 1.75 Income-Poverty Ratio                              NaN
# 2.0 Income-Poverty Ratio                               NaN
# Inflation                                              NaN
# 2010 Cost Per Meal                               -0.081549
#
#                                  2010 Child Food Insecurity Rate  \
# 2010 Food Insecurity Rate                               0.917513
# ...

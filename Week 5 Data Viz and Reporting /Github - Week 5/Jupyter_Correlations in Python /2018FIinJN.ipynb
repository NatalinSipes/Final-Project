# %% [markdown]
# # 2018 Food Insecurity in JN

# %%
import pandas as pd
import seaborn
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
import numpy as np
from numpy import nan

# %% [markdown]
# # Import dataset

# %%
Feeding_People = pd.read_excel("C:/Users/NBrad/OneDrive/Desktop/Woz U/Final Project/Final Project Week 5/Stats2018.xlsx")

# %% [markdown]
# # .head()

# %%
Feeding_People.head()
# Out:
#         State  StateID  Unemployment_Rate(%)  Pop_Below_Poverty(%)  RPPall(%)  \
# 0     Alabama        0                   3.9                  16.0     87.968
# 1      Alaska        1                   6.5                  13.1    105.169
# 2     Arizona        2                   4.7                  12.8     97.638
# 3    Arkansas        3                   3.6                  15.9     88.360
# 4  California        4                   4.3                  11.9    110.755
#
#    Food_Insecurity(%  Child_FI(%)
# 0               12.9         18.1
# 1               17.0         23.1
# 2               17.3         23.1
# 3               13.1         19.0
# 4               10.8         15.2

# %% [markdown]
# # View columns and (copy & paste to make new dataframe)

# %%
Feeding_People.columns
# Out:
# Index(['State', 'StateID', 'Unemployment_Rate(%)', 'Pop_Below_Poverty(%)',
#        'RPPall(%)', 'Food_Insecurity(%', 'Child_FI(%)'],
#       dtype='object')

# %% [markdown]
# # Univariate Analysis

# %% [markdown]
# ## Common Data Types

# %%
Feeding_People.dtypes
# Out:
# State                    object
# StateID                   int64
# Unemployment_Rate(%)    float64
# Pop_Below_Poverty(%)    float64
# RPPall(%)               float64
# Food_Insecurity(%       float64
# Child_FI(%)             float64
# dtype: object

# %%
Feeding_People.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   State                 51 non-null     object
#  1   StateID               51 non-null     int64
#  2   Unemployment_Rate(%)  51 non-null     float64
#  3   Pop_Below_Poverty(%)  51 non-null     float64
#  4   RPPall(%)             51 non-null     float64
#  5   Food_Insecurity(%     51 non-null     float64
#  6   Child_FI(%)           51 non-null     float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 2.9+ KB

# %%
#//////////////////////////////////////////#
# Missing Values #
#/////////////////////////////////////////#

msno.matrix(Feeding_People) 
##This shows how many variables are missing or how many rows are missing.
#The White signifies missing and the gray singnifies that the value is there.
##This is a very important step in any EDA(Exploratory Data Anaylsis) you want to make sure you understand exactly what's 
##missing that way as a Data Scienctist or Data Analysist you can determing what you want to do with this in the future!
# Out:
# <AxesSubplot:>

# %% [markdown]
# # New Dataframe with only columns with numbers

# %%
Feeding_People1 = Feeding_People[['Unemployment_Rate(%)', 'Pop_Below_Poverty(%)', 'RPPall(%)', 'Food_Insecurity(%', 'Child_FI(%)']]
Feeding_People1.head()
# Out:
#    Unemployment_Rate(%)  Pop_Below_Poverty(%)  RPPall(%)  Food_Insecurity(%  \
# 0                   3.9                  16.0     87.968               12.9
# 1                   6.5                  13.1    105.169               17.0
# 2                   4.7                  12.8     97.638               17.3
# 3                   3.6                  15.9     88.360               13.1
# 4                   4.3                  11.9    110.755               10.8
#
#    Child_FI(%)
# 0         18.1
# 1         23.1
# 2         23.1
# 3         19.0
# 4         15.2

# %% [markdown]
# # Correlations

# %%
plt.figure(figsize=(8,8))
seaborn.heatmap(Feeding_People1.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,8))
sns.heatmap(Feeding_People1.corr(), annot=True, annot_kws={"size": 14})
sns.set_style('white')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

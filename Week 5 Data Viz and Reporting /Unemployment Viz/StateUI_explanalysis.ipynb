# %%
import pandas as pd

# %%
StateUI = pd.read_csv("AnnualStateUI.csv")
pd.set_option('display.max_columns', None)
StateUI.head()
# Out:
#         State       2009       2010       2011       2012      2013      2014  \
# 0     Alabama   9.816667  10.000000   9.366667   7.741667  6.608333  6.516667
# 1      Alaska   8.383333   8.100000   7.491667   7.166667  6.333333  6.541667
# 2     Arizona   8.458333   9.525000   9.216667   8.266667  7.975000  7.000000
# 3    Arkansas   7.041667   7.691667   7.975000   7.275000  7.325000  6.391667
# 4  California  11.616667  12.433333  11.841667  10.533333  8.891667  7.550000
#
#        2015      2016      2017  2018  2019  2020  2021
# 0  6.000000  5.858333  4.408333   3.9   3.0   6.5   3.4
# 1  6.533333  6.908333  7.141667   6.5   6.1   8.2   6.4
# 2  6.133333  5.375000  4.858333   4.7   4.7   7.7   4.9
# 3  5.408333  3.950000  3.666667   3.6   3.5   6.1   4.0
# 4  6.216667  5.483333  4.775000   4.3   4.0  10.2   7.3

# %%
StateUI
# Out:
#              State       2009       2010       2011       2012      2013  \
# 0          Alabama   9.816667  10.000000   9.366667   7.741667  6.608333
# 1           Alaska   8.383333   8.100000   7.491667   7.166667  6.333333
# 2          Arizona   8.458333   9.525000   9.216667   8.266667  7.975000
# 3         Arkansas   7.041667   7.691667   7.975000   7.275000  7.325000
# 4       California  11.616667  12.433333  11.841667  10.533333  8.891667
# 5         Colorado   7.275000   8.100000   8.575000   7.941667  6.908333
# 6      Connecticut   8.025000   9.016667   8.891667   8.325000  7.941667
# 7         Delaware   8.050000   8.666667   8.066667   6.841667  7.050000
# 8             D.C.  10.783333  10.466667  10.283333   9.108333  8.558333
# 9          Florida  10.416667  11.883333  10.725000   8.733333  7.050000
# 10         Georgia   9.791667  10.158333  10.050000   8.950000  8.308333
# 11          Hawaii   6.991667   6.550000   6.275000   6.041667  4.675000
# ...

# %%
StateUI.describe()
# Out:
#             2009       2010       2011       2012       2013       2014  \
# count  51.000000  51.000000  51.000000  51.000000  51.000000  51.000000
# mean    8.435131   8.759967   8.192484   7.362092   6.808333   5.812745
# std     2.110321   2.132889   1.958766   1.755489   1.565539   1.265384
# min     4.225000   3.808333   3.441667   3.050000   3.016667   2.700000
# 25%     6.845833   7.241667   7.120833   6.100000   5.520833   4.704167
# 50%     8.225000   8.866667   8.208333   7.275000   6.866667   6.016667
# 75%     9.937500  10.195833   9.466667   8.620833   8.037500   6.712500
# max    14.025000  13.966667  13.058333  11.691667   9.433333   7.966667
#
#             2015       2016       2017       2018       2019       2020  \
# count  51.000000  51.000000  51.000000  51.000000  51.000000  51.000000
# mean    5.083333   4.677614   4.196242   3.794118   3.621569   7.366667
# std     1.091131   1.004170   0.953570   0.830521   0.821782   1.884321
# ...

# %%
StateUI.dtypes
# Out:
# State     object
# 2009     float64
# 2010     float64
# 2011     float64
# 2012     float64
# 2013     float64
# 2014     float64
# 2015     float64
# 2016     float64
# 2017     float64
# 2018     float64
# 2019     float64
# 2020     float64
# 2021     float64
# dtype: object

# %% [markdown]
# ### Changing State From Object to Category Datatype

# %%
StateUI['State']=StateUI['State'].astype('category')

# %% [markdown]
# ### Subsetting Data Based on Year

# %%
unemp09 = StateUI.iloc[0:51,[0,1]]

# %%
unemp09
# Out:
#              State       2009
# 0          Alabama   9.816667
# 1           Alaska   8.383333
# 2          Arizona   8.458333
# 3         Arkansas   7.041667
# 4       California  11.616667
# 5         Colorado   7.275000
# 6      Connecticut   8.025000
# 7         Delaware   8.050000
# 8             D.C.  10.783333
# 9          Florida  10.416667
# 10         Georgia   9.791667
# 11          Hawaii   6.991667
# 12           Idaho   8.108333
# 13        Illinois   9.941667
# 14         Indiana   9.933333
# 15            Iowa   6.000000
# 16          Kansas   6.608333
# 17        Kentucky  10.375000
# 18       Louisiana   6.700000
# 19           Maine   8.216667
# 20        Maryland   7.083333
# 21   Massachusetts   8.508333
# 22        Michigan  14.025000
# 23       Minnesota   7.866667
# 24     Mississippi   9.441667
# 25        Missouri   9.008333
# 26         Montana   6.325000
# 27        Nebraska   4.650000
# 28          Nevada  11.758333
# 29   New Hampshire   6.466667
# ...

# %%
unemp09 = StateUI.iloc[0:51,[0,1]]
unemp10 = StateUI.iloc[0:51,[0,2]]
unemp11 = StateUI.iloc[0:51,[0,3]]
unemp12 = StateUI.iloc[0:51,[0,4]]
unemp13 = StateUI.iloc[0:51,[0,5]]
unemp14 = StateUI.iloc[0:51,[0,6]]
unemp15 = StateUI.iloc[0:51,[0,7]]
unemp16 = StateUI.iloc[0:51,[0,8]]
unemp17 = StateUI.iloc[0:51,[0,9]]
unemp18 = StateUI.iloc[0:51,[0,10]]
unemp19 = StateUI.iloc[0:51,[0,11]]
unemp20 = StateUI.iloc[0:51,[0,12]]
unemp21 = StateUI.iloc[0:51,[0,13]]

# %% [markdown]
# ### State Unemployment (%) - 2009

# %%
unemp09.hist()
# Out:
# array([[<AxesSubplot:title={'center':'2009'}>]], dtype=object)

# %%
unemp09.describe()
# Out:
#             2009
# count  51.000000
# mean    8.435131
# std     2.110321
# min     4.225000
# 25%     6.845833
# 50%     8.225000
# 75%     9.937500
# max    14.025000

# %%
unemp09.sort_values(['2009'], ascending = False).head(10)
# Out:
#              State       2009
# 22        Michigan  14.025000
# 39    Rhode Island  11.991667
# 28          Nevada  11.758333
# 40  South Carolina  11.700000
# 4       California  11.616667
# 37          Oregon  11.533333
# 33  North Carolina  10.808333
# 8             D.C.  10.783333
# 9          Florida  10.416667
# 17        Kentucky  10.375000

# %% [markdown]
# ### State Unemployment (%) - 2010

# %%
unemp10.hist()
# Out:
# array([[<AxesSubplot:title={'center':'2010'}>]], dtype=object)

# %%
unemp10.describe()
# Out:
#             2010
# count  51.000000
# mean    8.759967
# std     2.132889
# min     3.808333
# 25%     7.241667
# 50%     8.866667
# 75%    10.195833
# max    13.966667

# %%
unemp10.sort_values(['2010'], ascending = False).head(10)
# Out:
#              State       2010
# 28          Nevada  13.966667
# 22        Michigan  13.283333
# 4       California  12.433333
# 39    Rhode Island  12.041667
# 9          Florida  11.883333
# 40  South Carolina  11.258333
# 24     Mississippi  10.691667
# 37          Oregon  10.583333
# 8             D.C.  10.466667
# 13        Illinois  10.466667

# %% [markdown]
# ### State Unemployment (%) - 2011

# %%
unemp11.hist()
# Out:
# array([[<AxesSubplot:title={'center':'2011'}>]], dtype=object)

# %%
unemp11.describe()
# Out:
#             2011
# count  51.000000
# mean    8.192484
# std     1.958766
# min     3.441667
# 25%     7.120833
# 50%     8.208333
# 75%     9.466667
# max    13.058333

# %%
unemp11.sort_values(['2011'], ascending = False).head(10)
# Out:
#              State       2011
# 28          Nevada  13.058333
# 4       California  11.841667
# 39    Rhode Island  10.808333
# 9          Florida  10.725000
# 22        Michigan  10.441667
# 24     Mississippi  10.358333
# 40  South Carolina  10.316667
# 8             D.C.  10.283333
# 10         Georgia  10.050000
# 33  North Carolina   9.991667

# %% [markdown]
# ### State Unemployment (%) - 2012

# %%
unemp12.hist()
# Out:
# array([[<AxesSubplot:title={'center':'2012'}>]], dtype=object)

# %%
unemp12.describe()
# Out:
#             2012
# count  51.000000
# mean    7.362092
# std     1.755489
# min     3.050000
# 25%     6.100000
# 50%     7.275000
# 75%     8.620833
# max    11.691667

# %%
unemp12.sort_values(['2012'], ascending = False).head(10)
# Out:
#              State       2012
# 28          Nevada  11.691667
# 39    Rhode Island  10.758333
# 4       California  10.533333
# 33  North Carolina   9.541667
# 30      New Jersey   9.441667
# 8             D.C.   9.108333
# 40  South Carolina   9.016667
# 24     Mississippi   9.000000
# 10         Georgia   8.950000
# 22        Michigan   8.858333

# %% [markdown]
# ### State Unemployment (%) - 2013

# %%
unemp13.hist()
# Out:
# array([[<AxesSubplot:title={'center':'2013'}>]], dtype=object)

# %%
unemp13.describe()
# Out:
#             2013
# count  51.000000
# mean    6.808333
# std     1.565539
# min     3.016667
# 25%     5.520833
# 50%     6.866667
# 75%     8.037500
# max     9.433333

# %%
unemp13.sort_values(['2013'], ascending = False).head(10)
# Out:
#              State      2013
# 28          Nevada  9.433333
# 39    Rhode Island  9.116667
# 13        Illinois  9.108333
# 4       California  8.891667
# 24     Mississippi  8.816667
# 22        Michigan  8.725000
# 30      New Jersey  8.566667
# 33  North Carolina  8.566667
# 8             D.C.  8.558333
# 10         Georgia  8.308333

# %% [markdown]
# ### State Unemployment (%) - 2014

# %%
unemp14.hist()
# Out:
# array([[<AxesSubplot:title={'center':'2014'}>]], dtype=object)

# %%
unemp14.describe()
# Out:
#             2014
# count  51.000000
# mean    5.812745
# std     1.265384
# min     2.700000
# 25%     4.704167
# 50%     6.016667
# 75%     6.712500
# max     7.966667

# %%
unemp14.sort_values(['2014'], ascending = False).head(10)
# Out:
#            State      2014
# 39  Rhode Island  7.966667
# 28        Nevada  7.725000
# 24   Mississippi  7.608333
# 4     California  7.550000
# 8           D.C.  7.475000
# 10       Georgia  7.375000
# 22      Michigan  7.316667
# 13      Illinois  7.300000
# 17      Kentucky  7.108333
# 2        Arizona  7.000000

# %% [markdown]
# ### State Unemployment (%) - 2015

# %%
unemp15.hist()
# Out:
# array([[<AxesSubplot:title={'center':'2015'}>]], dtype=object)

# %%
unemp15.describe()
# Out:
#             2015
# count  51.000000
# mean    5.083333
# std     1.091131
# min     2.750000
# 25%     4.150000
# 50%     5.250000
# 75%     5.929167
# max     7.091667

# %%
unemp15.sort_values(['2015'], ascending = False).head(10)
# Out:
#              State      2015
# 8             D.C.  7.091667
# 48   West Virginia  6.858333
# 28          Nevada  6.841667
# 1           Alaska  6.533333
# 24     Mississippi  6.500000
# 31      New Mexico  6.425000
# 18       Louisiana  6.391667
# 40  South Carolina  6.225000
# 4       California  6.216667
# 2          Arizona  6.133333

# %% [markdown]
# ### State Unemployment (%) - 2016

# %%
unemp16.hist()
# Out:
# array([[<AxesSubplot:title={'center':'2016'}>]], dtype=object)

# %%
unemp16.describe()
# Out:
#             2016
# count  51.000000
# mean    4.677614
# std     1.004170
# min     2.858333
# 25%     3.920833
# 50%     4.816667
# 75%     5.320833
# max     6.908333

# %%
unemp16.sort_values(['2016'], ascending = False).head(10)
# Out:
#             State      2016
# 1          Alaska  6.908333
# 31     New Mexico  6.683333
# 8            D.C.  6.108333
# 48  West Virginia  6.083333
# 18      Louisiana  6.058333
# 0         Alabama  5.858333
# 24    Mississippi  5.841667
# 13       Illinois  5.816667
# 28         Nevada  5.733333
# 4      California  5.483333

# %% [markdown]
# ### State Unemployment (%) - 2017

# %%
unemp17.hist()
# Out:
# array([[<AxesSubplot:title={'center':'2017'}>]], dtype=object)

# %%
unemp17.describe()
# Out:
#             2017
# count  51.000000
# mean    4.196242
# std     0.953570
# min     2.358333
# 25%     3.504167
# 50%     4.258333
# 75%     4.775000
# max     7.141667

# %%
unemp17.sort_values(['2017'], ascending = False).head(10)
# Out:
#             State      2017
# 1          Alaska  7.141667
# 31     New Mexico  6.158333
# 8            D.C.  6.066667
# 48  West Virginia  5.183333
# 18      Louisiana  5.150000
# 24    Mississippi  5.108333
# 35           Ohio  5.041667
# 28         Nevada  5.041667
# 13       Illinois  4.975000
# 17       Kentucky  4.925000

# %% [markdown]
# ### State Unemployment (%) - 2018

# %%
unemp18.hist()
# Out:
# array([[<AxesSubplot:title={'center':'2018'}>]], dtype=object)

# %%
unemp18.describe()
# Out:
#             2018
# count  51.000000
# mean    3.794118
# std     0.830521
# min     2.500000
# 25%     3.200000
# 50%     3.800000
# 75%     4.250000
# max     6.500000

# %%
unemp18.sort_values(['2018'], ascending = False).head(10)
# Out:
#             State  2018
# 1          Alaska   6.5
# 8            D.C.   5.7
# 48  West Virginia   5.2
# 18      Louisiana   4.9
# 31     New Mexico   4.9
# 24    Mississippi   4.8
# 2         Arizona   4.7
# 35           Ohio   4.5
# 47     Washington   4.5
# 28         Nevada   4.4

# %% [markdown]
# ### State Unemployment (%) - 2019

# %%
unemp19.hist()
# Out:
# array([[<AxesSubplot:title={'center':'2019'}>]], dtype=object)

# %%
unemp19.describe()
# Out:
#             2019
# count  51.000000
# mean    3.621569
# std     0.821782
# min     2.400000
# 25%     3.000000
# 50%     3.500000
# 75%     4.000000
# max     6.100000

# %%
unemp19.sort_values(['2019'], ascending = False).head(10)
# Out:
#             State  2019
# 1          Alaska   6.1
# 8            D.C.   5.5
# 24    Mississippi   5.4
# 31     New Mexico   4.9
# 48  West Virginia   4.9
# 18      Louisiana   4.8
# 2         Arizona   4.7
# 38   Pennsylvania   4.4
# 47     Washington   4.3
# 17       Kentucky   4.3

# %% [markdown]
# ### State Unemployment (%) - 2020

# %%
unemp20.hist()
# Out:
# array([[<AxesSubplot:title={'center':'2020'}>]], dtype=object)

# %%
unemp20.describe()
# Out:
#             2020
# count  51.000000
# mean    7.366667
# std     1.884321
# min     4.100000
# 25%     6.100000
# 50%     7.200000
# 75%     8.200000
# max    13.500000

# %%
unemp20.sort_values(['2020'], ascending = False).head(10)
# Out:
#             State  2020
# 28         Nevada  13.5
# 11         Hawaii  12.0
# 4      California  10.2
# 22       Michigan  10.0
# 32       New York   9.9
# 30     New Jersey   9.5
# 21  Massachusetts   9.4
# 39   Rhode Island   9.2
# 13       Illinois   9.2
# 38   Pennsylvania   9.1

# %% [markdown]
# ### State Unemployment (%) - 2021

# %%
unemp21.hist()
# Out:
# array([[<AxesSubplot:title={'center':'2021'}>]], dtype=object)

# %%
unemp21.describe()
# Out:
#             2021
# count  51.000000
# mean    4.839216
# std     1.238399
# min     2.500000
# 25%     3.800000
# 50%     4.800000
# 75%     5.700000
# max     7.300000

# %%
unemp21.sort_values(['2021'], ascending = False).head(10)
# Out:
#            State  2021
# 4     California   7.3
# 28        Nevada   7.2
# 32      New York   6.9
# 31    New Mexico   6.8
# 8           D.C.   6.6
# 1         Alaska   6.4
# 30    New Jersey   6.3
# 38  Pennsylvania   6.3
# 6    Connecticut   6.3
# 13      Illinois   6.1

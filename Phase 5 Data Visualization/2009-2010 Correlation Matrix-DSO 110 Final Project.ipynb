# %% [markdown]
# # Imports

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import missingno as msno
import numpy as np
from numpy import nan

# %% [markdown]
# # Read-In-Data

# %%
Food_Insecurities = pd.read_excel("C:/Users/Ivette/OneDrive/New folder/DSO 110 Final Project/Correlation Matrix 2009.xlsx")

# %% [markdown]
# # Head()
# ### Best way to always call your datasets to insure it's properly loaded up

# %%
Food_Insecurities.tail()
# Out:
#    State  Food Insecurity   Child Food Insecurity  Unemployment Rate  \
# 46    VT             0.133                  0.207           0.068833
# 47    WA             0.148                  0.247           0.090667
# 48    WI             0.131                  0.226           0.084167
# 49    WV             0.140                  0.220           0.080333
# 50    WY             0.121                  0.206           0.057917
#
#     0.5 Income-Poverty Ratio  0.75 Income-Poverty Ratio  \
# 46                     0.063                      0.099
# 47                     0.063                      0.099
# 48                     0.063                      0.099
# 49                     0.063                      0.099
# 50                     0.063                      0.099
#
#     1.0 Income-Poverty Ratio  1.25 Income-Poverty Ratio  \
# 46                     0.143                      0.187
# 47                     0.143                      0.187
# ...

# %%
#View columns and (copy & paste to make new dataframe)
Food_Insecurities.columns
# Out:
# Index(['State', 'Food Insecurity ', 'Child Food Insecurity',
#        'Unemployment Rate', '0.5 Income-Poverty Ratio',
#        '0.75 Income-Poverty Ratio', '1.0 Income-Poverty Ratio',
#        '1.25 Income-Poverty Ratio', '1.5 Income-Poverty Ratio',
#        '1.75 Income-Poverty Ratio', '2.0 Income-Poverty Ratio', 'Inflation'],
#       dtype='object')

# %% [markdown]
# # Univariate Analysis
#
# ## Common Data Types

# %%
#///////////////////////////////////////////////////#
# Data Types #
#//////////////////////////////////////////////////#

Food_Insecurities.dtypes
# Out:
# State                         object
# Food Insecurity              float64
# Child Food Insecurity        float64
# Unemployment Rate            float64
# 0.5 Income-Poverty Ratio     float64
# 0.75 Income-Poverty Ratio    float64
# 1.0 Income-Poverty Ratio     float64
# 1.25 Income-Poverty Ratio    float64
# 1.5 Income-Poverty Ratio     float64
# 1.75 Income-Poverty Ratio    float64
# 2.0 Income-Poverty Ratio     float64
# Inflation                    float64
# dtype: object

# %%
Food_Insecurities.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   State                      51 non-null     object
#  1   Food Insecurity            51 non-null     float64
#  2   Child Food Insecurity      51 non-null     float64
#  3   Unemployment Rate          51 non-null     float64
#  4   0.5 Income-Poverty Ratio   51 non-null     float64
#  5   0.75 Income-Poverty Ratio  51 non-null     float64
#  6   1.0 Income-Poverty Ratio   51 non-null     float64
#  7   1.25 Income-Poverty Ratio  51 non-null     float64
#  8   1.5 Income-Poverty Ratio   51 non-null     float64
#  9   1.75 Income-Poverty Ratio  51 non-null     float64
#  10  2.0 Income-Poverty Ratio   51 non-null     float64
# dtypes: float64(10), object(1)
# memory usage: 4.5+ KB

# %%
Food_Insecurities.isna()
# Out:
#     State  Food Insecurity   Child Food Insecurity  Unemployment Rate  \
# 0   False             False                  False              False
# 1   False             False                  False              False
# 2   False             False                  False              False
# 3   False             False                  False              False
# 4   False             False                  False              False
# 5   False             False                  False              False
# 6   False             False                  False              False
# 7   False             False                  False              False
# 8   False             False                  False              False
# 9   False             False                  False              False
# 10  False             False                  False              False
# 11  False             False                  False              False
# ...

# %%
Food_Insecurities.isnull()
# Out:
#     State  Food Insecurity   Child Food Insecurity  Unemployment Rate  \
# 0   False             False                  False              False
# 1   False             False                  False              False
# 2   False             False                  False              False
# 3   False             False                  False              False
# 4   False             False                  False              False
# 5   False             False                  False              False
# 6   False             False                  False              False
# 7   False             False                  False              False
# 8   False             False                  False              False
# 9   False             False                  False              False
# 10  False             False                  False              False
# 11  False             False                  False              False
# ...

# %%
#//////////////////////////////////////////#
# Missing Values #
#/////////////////////////////////////////#

msno.matrix(Food_Insecurities) 
##This shows how many variables are missing or how many rows are missing.
#The White signifies missing and the gray singnifies that the value is there.
##This is a very important step in any EDA(Exploratory Data Anaylsis) you want to make sure you understand exactly what's 
##missing that way as a Data Scienctist or Data Analysist you can determing what you want to do with this in the future!
# Out:
# <AxesSubplot:>

# %%
#New Dataframe with only columns with numbers
Food_Insecurities1 = Food_Insecurities[['State', 'Food Insecurity ', 'Child Food Insecurity', 'Unemployment Rate']]
Food_Insecurities1.head()
# Out:
#   State  Food Insecurity   Child Food Insecurity  Unemployment Rate
# 0    AK             0.135                  0.212           0.083833
# 1    AL             0.178                  0.266           0.098167
# 2    AR             0.178                  0.286           0.070417
# 3    AZ             0.174                  0.288           0.084583
# 4    CA             0.167                  0.273           0.116167

# %% [markdown]
# # Correlation

# %%
Food_Insecurities1.corr()
# Out:
#                        Food Insecurity   Child Food Insecurity  \
# Food Insecurity                1.000000               0.911901
# Child Food Insecurity          0.911901               1.000000
# Unemployment Rate              0.632815               0.608743
#
#                        Unemployment Rate
# Food Insecurity                 0.632815
# Child Food Insecurity           0.608743
# Unemployment Rate               1.000000

# %% [markdown]
# # Seaborn Correlation Heatmap

# %%
plt.figure(figsize=(8,8))
seaborn.heatmap(Food_Insecurities1.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Matplotlib Correlation Heatmap

# %%
plt.figure(figsize=(16,9))
sns.heatmap(Food_Insecurities1.corr(), annot=True, annot_kws={"size": 14})
sns.set_style('white')
plt.xticks(fontsize=14)
plt.yticks(fontsize=14)
plt.show()

# %% [markdown]
# # Read-In-Data

# %%
Food_Insecurities2 = pd.read_excel("C:/Users/Ivette/OneDrive/New folder/DSO 110 Final Project/Correlation Matrix 2010.xlsx")
Food_Insecurities2.head(50)
# Out:
#    State  2010 Food Insecurity Rate  2010 Child Food Insecurity Rate  \
# 0     AK                      0.146                            0.199
# 1     AL                      0.192                            0.267
# 2     AR                      0.192                            0.278
# 3     AZ                      0.190                            0.290
# 4     CA                      0.171                            0.268
# 5     CO                      0.155                            0.221
# 6     CT                      0.138                            0.188
# 7     DC                      0.165                            0.307
# 8     DE                      0.128                            0.184
# 9     FL                      0.192                            0.284
# 10    GA                      0.199                            0.283
# 11    HI                      0.140                            0.217
# 12    IA                      0.134                            0.195
# ...

# %%
#View columns and (copy & paste to make new dataframe)
Food_Insecurities2.columns
# Out:
# Index(['State', '2010 Food Insecurity Rate', '2010 Child Food Insecurity Rate',
#        'Unemployment Rate', '2010 Cost Per Meal'],
#       dtype='object')

# %% [markdown]
# # Univariate Analysis
#
# ## Common Data Types

# %%
#///////////////////////////////////////////////////#
# Data Types #
#//////////////////////////////////////////////////#

Food_Insecurities2.dtypes
# Out:
# State                               object
# 2010 Food Insecurity Rate          float64
# 2010 Child Food Insecurity Rate    float64
# Unemployment Rate                  float64
# 2010 Cost Per Meal                 float64
# dtype: object

# %%
Food_Insecurities2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51 entries, 0 to 50
# Data columns (total 5 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   State                            51 non-null     object
#  1   2010 Food Insecurity Rate        51 non-null     float64
#  2   2010 Child Food Insecurity Rate  51 non-null     float64
#  3   Unemployment Rate                51 non-null     float64
#  4   2010 Cost Per Meal               51 non-null     float64
# dtypes: float64(4), object(1)
# memory usage: 2.1+ KB

# %%
Food_Insecurities2.isna()
# Out:
#     State  2010 Food Insecurity Rate  2010 Child Food Insecurity Rate  \
# 0   False                      False                            False
# 1   False                      False                            False
# 2   False                      False                            False
# 3   False                      False                            False
# 4   False                      False                            False
# 5   False                      False                            False
# 6   False                      False                            False
# 7   False                      False                            False
# 8   False                      False                            False
# 9   False                      False                            False
# 10  False                      False                            False
# 11  False                      False                            False
# ...

# %%
Food_Insecurities2.isnull()
# Out:
#     State  2010 Food Insecurity Rate  2010 Child Food Insecurity Rate  \
# 0   False                      False                            False
# 1   False                      False                            False
# 2   False                      False                            False
# 3   False                      False                            False
# 4   False                      False                            False
# 5   False                      False                            False
# 6   False                      False                            False
# 7   False                      False                            False
# 8   False                      False                            False
# 9   False                      False                            False
# 10  False                      False                            False
# 11  False                      False                            False
# ...

# %%
#//////////////////////////////////////////#
# Missing Values #
#/////////////////////////////////////////#

msno.matrix(Food_Insecurities) 
##This shows how many variables are missing or how many rows are missing.
#The White signifies missing and the gray singnifies that the value is there.
##This is a very important step in any EDA(Exploratory Data Anaylsis) you want to make sure you understand exactly what's 
##missing that way as a Data Scienctist or Data Analysist you can determing what you want to do with this in the future!
# Out:
# <AxesSubplot:>

# %%
#New Dataframe with only columns with numbers
Food_Insecurities3 = Food_Insecurities2[['State', '2010 Food Insecurity Rate', '2010 Child Food Insecurity Rate', 'Unemployment Rate', '2010 Cost Per Meal']]
Food_Insecurities3.head()
# Out:
#   State  2010 Food Insecurity Rate  2010 Child Food Insecurity Rate  \
# 0    AK                      0.146                            0.199
# 1    AL                      0.192                            0.267
# 2    AR                      0.192                            0.278
# 3    AZ                      0.190                            0.290
# 4    CA                      0.171                            0.268
#
#    Unemployment Rate  2010 Cost Per Meal
# 0           8.100000                2.67
# 1          10.000000                2.48
# 2           7.691667                2.40
# 3           9.525000                2.40
# 4          12.433333                2.55

# %% [markdown]
# # Correlation

# %%
Food_Insecurities3.corr()
# Out:
#                                  2010 Food Insecurity Rate  \
# 2010 Food Insecurity Rate                         1.000000
# 2010 Child Food Insecurity Rate                   0.917513
# Unemployment Rate                                 0.646878
# 2010 Cost Per Meal                               -0.081549
#
#                                  2010 Child Food Insecurity Rate  \
# 2010 Food Insecurity Rate                               0.917513
# 2010 Child Food Insecurity Rate                         1.000000
# Unemployment Rate                                       0.618980
# 2010 Cost Per Meal                                      0.045930
#
#                                  Unemployment Rate  2010 Cost Per Meal
# 2010 Food Insecurity Rate                 0.646878           -0.081549
# 2010 Child Food Insecurity Rate           0.618980            0.045930
# Unemployment Rate                         1.000000            0.183279
# ...

# %% [markdown]
# # Seaborn Correlation Heatmap

# %%
plt.figure(figsize=(8,8))
seaborn.heatmap(Food_Insecurities3.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Matplotlib Correlation Heatmap

# %%
plt.figure(figsize=(16,10))
sns.heatmap(Food_Insecurities3.corr(), annot=True, annot_kws={"size": 14})
sns.set_style('white')
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()
